# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from sklearn.decomposition import PCA, IncrementalPCA

# %% [markdown]
# # Read input data

# %%
# Read input data
x_train = pd.read_csv("./data/X_train.csv")
y_train = pd.read_csv("./data/y_train.csv")

test_data = pd.read_csv("./data/X_test.csv")
x_test = test_data.drop("id", axis=1)
id_test = test_data["id"]

del x_train['id']
del y_train["id"]

# %%
x_train.shape
# Out:
# (4800, 1000)

# %% [markdown]
# ### Data Visualization

# %%
n_components = 2
ipca = IncrementalPCA(n_components=n_components, batch_size=10)
X_ipca = ipca.fit_transform(x_train)

# %%
colors = ['navy', 'turquoise', 'darkorange']
targets = np.unique(y_train.values)
plt.figure(figsize=(8, 8))
for color, i, target_name in zip(colors, [0, 1, 2], targets):
    plt.scatter(X_ipca[y_train.values.flatten() == i, 0], X_ipca[y_train.values.flatten() == i, 1],
                    color=color, lw=2, label=target_name)

plt.title("IPCA of train_data")    
plt.legend(loc="best", shadow=False, scatterpoints=1)
plt.axis([-40, 45, -40, 25])
plt.savefig('pca_train_data')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.scatter(X_ipca[y_train.values.flatten() == 0, 0], X_ipca[y_train.values.flatten() == 0, 1],
                    color='navy', lw=2, label=0)
plt.title("IPCA of train_data of class 0") 
plt.savefig('pca_train_data_class0')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.scatter(X_ipca[y_train.values.flatten() == 1, 0], X_ipca[y_train.values.flatten() == 1, 1],
                    color='turquoise', lw=2, label=0)
plt.title("IPCA of train_data of class 0") 
plt.savefig('pca_train_data_class1')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.scatter(X_ipca[y_train.values.flatten() == 2, 0], X_ipca[y_train.values.flatten() == 2, 1],
                    color='darkorange', lw=2, label=0)
plt.title("IPCA of train_data of class 0") 
plt.savefig('pca_train_data_class2')
plt.show()
